# %%
#break statement and continue statement
#the break statement enables a program to skip over a part of the code. A break statement terminates the very loop it lies within.

for i in range(12) :
  print(i * 5)
  if (i==10):
    break
print("loop ko chod kar nikal gaya")

#break means loop ko chodkar nikal jao
#continuation matlab iteration ko chodkar nikal jao.
# Out:
# 0
# 5
# 10
# 15
# 20
# 25
# 30
# 35
# 40
# 45
# 50
# loop ko chod kar nikal gaya

# %%
for i in range(15) :
  print(i * 5)
  if (i==10):
    print("skip the iteration ")
    continue
# Out:
# 0
# 5
# 10
# 15
# 20
# 25
# 30
# 35
# 40
# 45
# 50
# skip the iteration
# 55
# 60
# 65
# 70

# %%
#do while loop
while True:
    num = int(input("Enter a number (0 to stop): "))
    print("You entered:", num)

    if num == 0:
        break
# Out:
# Enter a number (0 to stop): ५
# You entered: 5
# Enter a number (0 to stop): ६
# You entered: 6
# Enter a number (0 to stop): ०
# You entered: 0

# %%
while True:
    num = int(input("Enter a number (0 to stop): "))
    print("You entered:", num)

    if num == 0:
        continue
# Out:
# Enter a number (0 to stop): ५
# You entered: 5
# Enter a number (0 to stop): ७
# You entered: 7
# Enter a number (0 to stop): ०
# You entered: 0

# %%
🔸 break

Stops the entire loop completely.

Python jumps out of the loop — it doesn’t come back.

The loop ends right there.


🧠 Think of it like saying:

> “Okay, enough! I’m done looping.”

# %%
🔸 continue

Doesn’t stop the loop.

It only skips the rest of the code inside the loop for this one round,
and then goes back to the top to start the next round.


🧠 Think of it like saying:

> “I’ll skip this one and move on to the next turn.”
