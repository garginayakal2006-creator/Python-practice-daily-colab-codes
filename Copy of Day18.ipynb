# %%
#while loop
#-while loop executes statements while the condition is true.
#-as soon as condition becomes false, the interpreter comes out of the while loop.

i=int(input("enter your num:"))
while (i<=38):
 i=int(input("enter your num:"))
 print(i)
# Out:
# enter your num:5
# enter your num:38
# 38
# enter your num:36
# 36
# enter your num:32
# 32
# enter your num:39
# 39

# %%
count=5
while (count>0) :
  print(count)
  count=count-1o
# Out:
# 5
# 4
# 3
# 2
# 1
